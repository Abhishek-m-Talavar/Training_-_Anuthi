# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 

roll_no=[1,2,3,4,5,6,7]
marks=[33,44,24,65,77,33,56]
df=pd.DataFrame({'Roll_No':roll_no,"Marks":marks})
print(df)
sns.lineplot(x='Roll_No',y='Marks', data=df)
plt.title('Student Marks Info')
plt.show()
# Out:
#    Roll_No  Marks
# 0        1     33
# 1        2     44
# 2        3     24
# 3        4     65
# 4        5     77
# 5        6     33
# 6        7     56

# %%
seaborn_data=pd.read_csv('hr_data.csv')
seaborn_data.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='number_project', y='average_montly_hours', data=seaborn_data, hue='department')
# Out:
# <Axes: xlabel='number_project', ylabel='average_montly_hours'>

# %%
# 2) Displot

# %%
sns.distplot(seaborn_data['time_spend_company'])
# Out:
# C:\Users\abhi\AppData\Local\Temp\ipykernel_4124\772576654.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(seaborn_data['time_spend_company'])
# <Axes: xlabel='time_spend_company', ylabel='Density'>

# %%
sns.histplot(seaborn_data['time_spend_company'], kde=True)
# Out:
# <Axes: xlabel='time_spend_company', ylabel='Count'>

# %%
sns.distplot(seaborn_data['time_spend_company'],  bins=5)
plt.xticks(bins)
# Out:
# C:\Users\abhi\AppData\Local\Temp\ipykernel_4124\2309397091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(seaborn_data['time_spend_company'],  bins=5)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 sns.distplot(seaborn_data['time_spend_company'],  bins=5)
# ----> 2 plt.xticks(bins)
#
# NameError: name 'bins' is not defined

# %%
sea=sns.load_dataset('titanic')
sea.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(x='age', y='fare',data=sea, hue='alive')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# 5) Heatmap()

# %%
heat=sns.load_dataset('flights')
heat.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
xa=heat.pivot(index='month', columns='year',values='passengers')
xa.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
plt.figure(figsize=(12,6))
x=sns.heatmap(xa, annot=True, fmt='d')
